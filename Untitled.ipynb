# %%
import pandas as pd 
import numpy as np 
from sklearn.linear_model import LinearRegression 
import matplotlib.pyplot as plt

# %%
data=pd.read_csv('suv_data.csv')
df=pd.DataFrame(data)

# %%
df.drop(columns='User ID',inplace=True)

# %%
df['Gender'].replace({"Male":1,"Female":0},inplace=True)
# Out:
# C:\Users\Gaurav Rao\AppData\Local\Temp\ipykernel_7564\1797557426.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Gender'].replace({"Male":1,"Female":0},inplace=True)
# C:\Users\Gaurav Rao\AppData\Local\Temp\ipykernel_7564\1797557426.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['Gender'].replace({"Male":1,"Female":0},inplace=True)

# %%
x=df.drop(columns=['Purchased'])
y=df['Purchased']

# %%
x
# Out:
#      Gender  Age  EstimatedSalary
# 0         1   19            19000
# 1         1   35            20000
# 2         0   26            43000
# 3         0   27            57000
# 4         1   19            76000
# ..      ...  ...              ...
# 395       0   46            41000
# 396       1   51            23000
# 397       0   50            20000
# 398       1   36            33000
# 399       0   49            36000
#
# [400 rows x 3 columns]

# %%
from sklearn.linear_model import LogisticRegression 
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
print(x_train,x_test)
# Out:
#      Gender  Age  EstimatedSalary
# 3         0   27            57000
# 18        1   46            28000
# 202       0   39           134000
# 250       0   44            39000
# 274       0   57            26000
# ..      ...  ...              ...
# 71        0   24            27000
# 106       0   26            35000
# 270       0   43           133000
# 348       1   39            77000
# 102       0   32            86000
#
# [320 rows x 3 columns]      Gender  Age  EstimatedSalary
# 209       0   46            22000
# 280       0   59            88000
# 33        0   28            44000
# 210       0   48            96000
# 93        0   29            28000
# ..      ...  ...              ...
# 246       0   35            50000
# 227       1   56           133000
# 369       0   54            26000
# 176       0   35            47000
# 289       0   37            78000
#
# [80 rows x 3 columns]

# %%
from sklearn.pipeline import Pipeline

# %%
pipeline=Pipeline([('scaler',StandardScaler()),('model',LogisticRegression())])

# %%
pipeline.fit(x_train,y_train)
# Out:
# Pipeline(steps=[('scaler', StandardScaler()), ('model', LogisticRegression())])

# %%
y_pred=pipeline.predict(x_test)

# %%
# accuracy -- 
print(accuracy_score(y_test,y_pred))
# Out:
# 0.8875

# %%
import pickle 
pickle.dump(pipeline,open('model.pkl','wb'))

# %%
# Out:
# accuracy:  0.8875
